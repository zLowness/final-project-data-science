# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, we will explore various tools and concepts used in Data Science.

# %% [markdown]
# ## Popular Data Science Languages
#
# Some of the most commonly used languages in Data Science are:
# 1. Python
# 2. R
# 3. SQL
# 4. Julia
# 5. Scala

# %% [markdown]
# ## Commonly Used Data Science Libraries
#
# Here are some popular libraries used by Data Scientists:
# - Pandas
# - NumPy
# - Matplotlib
# - Scikit-learn
# - TensorFlow

# %% [markdown]
# ## Data Science Tools
#
# | Tool           | Description                        |
# |----------------|------------------------------------|
# | Jupyter        | Interactive notebook environment   |
# | RStudio        | IDE for R                          |
# | Apache Spark   | Big Data processing framework      |
# | TensorFlow     | Deep learning library              |
# | VS Code        | Lightweight coding IDE             |

# %% [markdown]
# ### Examples of Arithmetic Expressions
#
# Below are some examples of simple arithmetic expressions:
#
# - `5 + 3` results in 8
# - `4 * 6` results in 24
# - `(10 - 2) / 4` results in 2

# %%
# Multiply and add two numbers
(3 * 4) + 5

# %%
# Convert minutes to hours
minutes = 150
hours = minutes / 60
hours

# %%
# List of objectives
objectives = [
    "Understand Data Science tools",
    "Learn popular Data Science languages",
    "Use Markdown in Jupyter notebooks",
    "Perform basic arithmetic in code cells"
]
for obj in objectives:
    print("-", obj)

# %% [markdown]
# **Author:** Your Name Here
